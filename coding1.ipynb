# %% [markdown]
# <a href="https://colab.research.google.com/github/HACK0018/training-program/blob/main/coding1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("enter total no:monkey:" ))
k=int(input("enter banana a monkey can eat:" ))
j=int(input("enter Peanut a monkey can eat:" ))
m=int(input("enter total no:bananas:"))
p=int(input("enter total no:peanuts:" ))
if(k==0 or j==0):
  print("invalid input")
else:
  n=n-(m//k+p//j)
  if(m%k!=0 or p%j!=0):
    n=n-1
  print("No of monkeys in tree:",n)
# Out:
# enter total no:monkey:20
# enter banana a monkey can eat:2
# enter Peanut a monkey can eat:3
# enter total no:bananas:13
# enter total no:peanuts:13
# No of monkeys in tree: 9

# %%
a=int(input("enter a number:"))
b=int(input("enter a number:"))
a,b=b,a
print("a=",a)
print("b=",b)
# Out:
# enter a number:5
# enter a number:7
# a= 7
# b= 5

# %%
a=int(input("enter a number:"))
b=int(input("enter a number:"))
a=a+b
b=a-b
a=a-b
print("a=",a)
print("b=",b)
# Out:
# enter a number:6
# enter a number:4
# a= 4
# b= 6

# %%
a=int(input("enter a number:"))
b=int(input("enter a number:"))
a=a^b
b=a^b
a=a^b
print("a=",a)
print("b=",b)
# Out:
# enter a number:5
# enter a number:7
# a= 7
# b= 5

# %%
a=5
b=7
print("by using 3rd variable")
c=a
a=b
b=c
print("a=",a)
print("b=",b)
print("without using 3rd variable")
a=5
b=7
a,b=b,a
print("a=",a)
print("b=",b)
print("by using + or-")
a=5
b=7
a=a+b
b=a-b
a=a-b
print("a=",a)
print("b=",b)
print( "by using xor operator")
a=5
b=7
a=a^b
b=a^b
a=a^b
print("a=",a)
print("b=",b)
# Out:
# by using 3rd variable
# a= 7
# b= 5
# without using 3rd variable
# a= 7
# b= 5
# by using + or-
# a= 7
# b= 5
# by using xor operator
# a= 7
# b= 5

# %%
n=int(input("enter no:of candies available in the jar"))
k=int(input("enter number of minimum candies that must be inside JAR ever."))
C=1
R=n
while(C==1):
  M=int(input("Enter amout of candies needed:"))
  if(M>n):
    print("invalid")
  else:
    R=R-M
    if(R<=k):
      R=n
    print("SOLD=",M)
    print("Remaining=",R)
    C=int(input("DO you want to continue(1or0):"))
# Out:
# enter no:of candies available in the jar10
# enter number of minimum candies that must be inside JAR ever.5
# Enter amout of candies needed:2
# SOLD= 2
# Remaining= 8
# DO you want to continue(1or0):1
# Enter amout of candies needed:3
# SOLD= 3
# Remaining= 10
